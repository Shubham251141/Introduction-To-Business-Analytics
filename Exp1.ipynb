# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham251141/Introduction-To-Business-Analytics/blob/main/Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-edfdeff9-fe66-4abb-99f9-def2881cf681" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-edfdeff9-fe66-4abb-99f9-def2881cf681">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

data = pd.read_csv('Lab1.csv')
print(data.head(6))
# Out:
#      <input type="file" id="files-af83d77a-3bb5-4034-ba8d-af8c199e8a1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af83d77a-3bb5-4034-ba8d-af8c199e8a1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from scipy.stats import trim_mean

# %%
data = pd.read_csv("Lab1.csv")

# Check the type of data
print ("Type : ", type(data), "\n\n")

# Printing Top 10 Records
print ("Head -- \n", data.head(10))

# Printing last 10 Records
print ("\n\n Tail -- \n", data.tail(10))
# Out:
# Type :  <class 'pandas.core.frame.DataFrame'>
#
#
# Head --
#             NAME     COMPANY NAME  SALARY   AGE  HEIGHT(in cm)
# 0           NaN              NaN     NaN   NaN            NaN
# 1  Aarav Sharma  PQR Enterprises  $60000  20.0          183.0
# 2         Rohan  PQR Enterprises  $60001  21.0          145.0
# 3         sneha  PQR Enterprises  $60002  24.0          123.0
# 4        rajash  PQR Enterprises  $60003  56.0          145.0
# 5        vikash  PQR Enterprises  $60004  24.0          165.0
# 6        aditya  PQR Enterprises  $60005  55.0          174.0
# 7    abhinandan  PQR Enterprises  $60006  24.0          153.0
# 8         ankit  PQR Enterprises  $60007  45.0          123.0
# 9         Rahul  PQR Enterprises  $60008  48.0          147.0
#
#
#  Tail --
#            NAME     COMPANY NAME  SALARY   AGE  HEIGHT(in cm)
# 5       vikash  PQR Enterprises  $60004  24.0          165.0
# 6       aditya  PQR Enterprises  $60005  55.0          174.0
# ...
